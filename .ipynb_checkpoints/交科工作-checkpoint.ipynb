# %%
import pandas as pd
import numpy as py

# %%
fpath1=r'C:\Users\刘佳琦\Desktop\交科初审评分表.xlsx'
fpath2=r'C:\Users\刘佳琦\Desktop\道路-轨道-交通 交科网络评审汇总表09232226-2240.xlsx'
df_1 = pd.read_excel(fpath1)
df_2 = pd.read_excel(fpath2)

# %%
df_2
# Out:
#    第十九届交通科技大赛                    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN                           NaN        NaN        NaN       网评评委
# 1          编号                          课题名称         组长       指导老师        评委1
# 2        交通规划                           NaN        NaN        NaN        NaN
# 3           1            基于情景意识模型的智能车运行风险预警        王卓非        余荣杰        NaN
# 4           2       基于知识图谱技术的异常驾驶行为智能辨识方法研究        李兆祥        余荣杰        NaN
# ..        ...                           ...        ...        ...        ...
# 71          2             高铁成网条件下铁路旅客行前规划系统        黄子函         朱炜         洪玲
# 72          3            城市轨道交通非常态大客流管控方法研究         杨帆         朱炜         洪玲
# 73          4           基于wifi嗅探数据的地铁异常乘客识别        龚帅宇        江志彬         朱炜
# 74          5                  公交大站快车停站优化设计        吴寅昇         滕靖         朱炜
# 75          6  依托城市轨道交通网络发展同城快递辅助系统的模式与方法研究        吴暐奇         朱炜         滕靖
#
#    Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8
# 0         NaN        NaN         NaN        NaN
# 1         评委2        评委3         NaN        NaN
# 2         NaN        NaN         NaN        NaN
# 3         NaN        NaN         NaN        余荣杰
# 4         NaN        NaN         NaN         柴晨
# ..        ...        ...         ...        ...
# 71        江志彬         滕靖         NaN         洪玲
# 72        江志彬         滕靖         NaN        江志彬
# 73         洪玲         滕靖         NaN         滕靖
# 74         洪玲        江志彬         NaN        NaN
# 75         洪玲        江志彬         NaN        NaN
#
# [76 rows x 9 columns]

# %%
df_daolu=df_2.iloc[52:61]
df_guidao=df_2.iloc[63:68]
df_yunshu=df_2.iloc[70:76]

# %%
df_guidao
# Out:
#    第十九届交通科技大赛          Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 63          1  地铁车内噪声与钢轨短波不平顺关系研究        张英杰        杨新文         王治        叶霞飞
# 64          2        宽频式钢轨吸振器降噪研究        王皓月        杨新文         王治        李新国
# 65          3   上海轨道交通换乘 APP 开发方案        廖怡伶         王治        杨新文        叶霞飞
# 66          4        轨道交通车厢拉手优化设计        赵冠华         王治        杨新文        叶霞飞
# 67          5        高铁车站商业开发业态研究        赵泽瑞         王治        杨新文        叶霞飞
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8
# 63        李新国         NaN         王治
# 64        李新国         NaN        杨新文
# 65        李新国         NaN        叶霞飞
# 66        李新国         NaN        李新国
# 67        李新国         NaN        NaN

# %%
a=df_guidao['Unnamed: 4']
b=df_guidao['Unnamed: 5']
c=df_guidao['Unnamed: 6']
d=df_guidao

# %%
d.iloc[1]['Unnamed: 4']
# Out:
# '王治'

# %%
name=['王治','杨新文','叶霞飞','李新国']#需要对每个方向更新  轨道系
dic={}
for i in name:
    list1=[]
    for j in range(len(d)):
        if (d.iloc[j]['Unnamed: 4']==i) or (d.iloc[j]['Unnamed: 5']==i) or (d.iloc[j]['Unnamed: 6']==i):
            list1.append(d['Unnamed: 1'])
    dic[i]=list1

# %%
dic
# Out:
# {'王治': [63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object],
#  '杨新文': [63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object],
#  '叶霞飞': [63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object],
#  '李新国': [63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object,
#   63    地铁车内噪声与钢轨短波不平顺关系研究
#   64          宽频式钢轨吸振器降噪研究
#   65     上海轨道交通换乘 APP 开发方案
#   66          轨道交通车厢拉手优化设计
#   67          高铁车站商业开发业态研究
#   Name: Unnamed: 1, dtype: object]}

# %%
df_yunshu
# Out:
#    第十九届交通科技大赛                    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 70          1              轨道交通乘客应急疏散预警体系研究        黄雪莎         洪玲         朱炜
# 71          2             高铁成网条件下铁路旅客行前规划系统        黄子函         朱炜         洪玲
# 72          3            城市轨道交通非常态大客流管控方法研究         杨帆         朱炜         洪玲
# 73          4           基于wifi嗅探数据的地铁异常乘客识别        龚帅宇        江志彬         朱炜
# 74          5                  公交大站快车停站优化设计        吴寅昇         滕靖         朱炜
# 75          6  依托城市轨道交通网络发展同城快递辅助系统的模式与方法研究        吴暐奇         朱炜         滕靖
#
#    Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8
# 70         滕靖        江志彬         NaN         朱炜
# 71        江志彬         滕靖         NaN         洪玲
# 72        江志彬         滕靖         NaN        江志彬
# 73         洪玲         滕靖         NaN         滕靖
# 74         洪玲        江志彬         NaN        NaN
# 75         洪玲        江志彬         NaN        NaN

# %%
name=['朱炜','洪玲','江志彬','滕靖']  #运输系老师
name=['']
