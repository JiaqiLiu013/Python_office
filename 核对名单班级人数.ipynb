# %%
import pandas as pd

# %%
dic1={1853932: '刘佳琦', 1853280: '胡雨辰', 1853447: '苏浩文', 1851872: '李兆祥',
 1850927: '李振铭', 1853804: '王思澄', 1852428: '刘旭东', 1850580: '赵东虎', 
 1851317: '蔡依林', 1854161: '张雪晨', 1853241: '李佳欣', 1751545: '李庆涛', 
 1852885: '马旭', 1852516: '简子涵', 1850933: '梁星', 1851923: '吕辰杰', 
 1853823: '王砚轩', 1850702: '王思涵', 1853363: '周洋', 1852544: '罗冠培', 
 1851878: '赵启晨', 1853937: '樊孟奇', 1850926: '金筱语', 1752804: '朱紫钰', 
 1853430: '孙乙月', 1852845: '孙颖聪', 1850275: '刘岳朋', 1853838: '徐子璇', 
 1850588: '蔡晋书', 1854171: '孙思薇', 1853566: '袁弋鸿', 1851179: '李晟', 
 1853699: '胡佳炜', 1851744: '叶倪瑄', 1853234: '冷帅', 1850630: '樊庶', 
 1852010: '戚美晨', 1852830: '王晨杨', 1851318: '汪芷瑶', 1851870: '丛诺', 
 1851655: '余韵婧', 1851338: '何佳萌', 1852823: '邓骞', 1750485: '马保贵'} #18级规划班全班同学信息建立字典
dic2={'刘佳琦': 1853932, '胡雨辰': 1853280, '苏浩文': 1853447, '李兆祥': 1851872, 
 '李振铭': 1850927, '王思澄': 1853804, '刘旭东': 1852428, '赵东虎': 1850580, 
 '蔡依林': 1851317, '张雪晨': 1854161, '李佳欣': 1853241, '李庆涛': 1751545, 
 '马旭': 1852885, '简子涵': 1852516, '梁星': 1850933, '吕辰杰': 1851923,
 '王砚轩': 1853823, '王思涵': 1850702, '周洋': 1853363, '罗冠培': 1852544,
 '赵启晨': 1851878, '樊孟奇': 1853937, '金筱语': 1850926, '朱紫钰': 1752804,
 '孙乙月': 1853430, '孙颖聪': 1852845, '刘岳朋': 1850275, '徐子璇': 1853838,
 '蔡晋书': 1850588, '孙思薇': 1854171, '袁弋鸿': 1853566, '李晟': 1851179, 
 '胡佳炜': 1853699, '叶倪瑄': 1851744, '冷帅': 1853234, '樊庶': 1850630, 
 '戚美晨': 1852010, '王晨杨': 1852830, '汪芷瑶': 1851318, '丛诺': 1851870, 
 '余韵婧': 1851655, '何佳萌': 1851338, '邓骞': 1852823, '马保贵': 1750485}   #18级规划班全班同学信息建立反向字典
name=['刘佳琦', '胡雨辰', '苏浩文', '李兆祥', '李振铭', '王思澄', '刘旭东', 
      '赵东虎', '蔡依林', '张雪晨', '李佳欣', '李庆涛', '马旭', '简子涵', '梁星',
      '吕辰杰', '王砚轩', '王思涵', '周洋', '罗冠培', '赵启晨', '樊孟奇', '金筱语',
      '朱紫钰', '孙乙月', '孙颖聪', '刘岳朋', '徐子璇', '蔡晋书', '孙思薇', '袁弋鸿',
      '李晟', '胡佳炜', '叶倪瑄', '冷帅', '樊庶', '戚美晨', '王晨杨', '汪芷瑶', '丛诺',
      '余韵婧', '何佳萌', '邓骞', '马保贵']  #18级规划班同学姓名
xuehao=['1853932', '1853280', '1853447', '1851872', '1850927', '1853804', 
        '1852428', '1850580', '1851317', '1854161', '1853241', '1751545', 
        '1852885', '1852516', '1850933', '1851923', '1853823', '1850702', 
        '1853363', '1852544', '1851878', '1853937', '1850926', '1752804', 
        '1853430', '1852845', '1850275', '1853838', '1850588', '1854171', 
        '1853566', '1851179', '1853699', '1851744', '1853234', '1850630', 
        '1852010', '1852830', '1851318', '1851870', '1851655', '1851338', 
        '1852823', '1750485']#18级规划班同学学号

# %%
name = list(dic1.values()) #获得所有姓名
xuehao = list(dic1.keys()) #获得所有学号
dic2 = {i:j for j, i in dic1.items()}#18级规划班全班同学信息建立反向字典

# %% [markdown]
# fp2=open(r"C:\Users\刘佳琦\Desktop\已有.txt",encoding="utf-8")  #使用于txt文本形式
# ##m=fp1.read()
# daoru=fp2.read()
# ##m=m.split('\n')
# daoru=daoru.split('\n')

# %%
fpath1=r"C:\Users\刘佳琦\Desktop\交规班寒假及返校情况调查.xlsx"
df1=pd.read_excel(fpath1)

# %%
df1
# Out:
#     序号 1、你的姓名   2、你的学号    3、你的返校日期 4、如果未能在2月28日之前返校，请填写未返校原因  \
# 0    1    刘佳琦  1853932  2021-02-25                       (空)
# 1    2    王思澄  1853804  2021-02-27                       (空)
# 2    3     梁星  1850933  2021-02-27                       (空)
# 3    4    刘旭东  1852428  2021-02-26                       (空)
# 4    5    苏浩文  1853447  2021-02-27                       (空)
# 5    6    李振铭  1850927  2021-02-27                       (空)
# 6    7    李庆涛  1751545  2021-02-27                       (空)
# 7    8    孙颖聪  1852845  2021-02-27                       (空)
# 8    9    金筱语  1850926  2021-02-27                       (空)
# 9   10    赵启晨  1851878  2021-02-27                       (空)
# 10  11    简子涵  1852516  2021-02-27                       (空)
# 11  12    马保贵  1750475  2021-02-27                       (空)
# 12  13    孙乙月  1853430  2021-02-27                       (空)
# 13  14    叶倪瑄  1851744  2021-02-27                       (空)
# ...

# %%
daoru=list(df1['1、你的姓名'])    #此方法是直接读取Excel 更加方便

# %%
daoru
# Out:
# ['刘佳琦',
#  '王思澄',
#  '梁星',
#  '刘旭东',
#  '苏浩文',
#  '李振铭',
#  '李庆涛',
#  '孙颖聪',
#  '金筱语',
#  '赵启晨',
#  '简子涵',
#  '马保贵',
#  '孙乙月',
#  '叶倪瑄',
#  '王晨杨',
#  '孙思薇',
#  '戚美晨',
#  '冷帅',
#  '李佳欣',
#  '胡雨辰',
#  '王思涵',
#  '胡佳炜',
#  '赵东虎',
#  '樊庶',
#  '周洋',
#  '吕辰杰',
#  '罗冠培',
#  '樊孟奇',
#  '余韵婧',
#  '朱紫钰',
#  '袁弋鸿',
#  '蔡晋书',
#  '刘岳朋',
#  '马旭',
#  '蔡依林',
#  '徐子璇',
#  '何佳萌',
#  '李晟',
#  '丛诺',
#  '李兆祥',
#  '王砚轩',
#  '汪芷瑶',
#  '邓骞']

# %%
t1=0
jilu1=[]
for i in name:
    if i  not in daoru:
        print(i)
        jilu1.append(i)
        t1+=1
print('共有{}人不在名单内'.format(t1))
# Out:
# 张雪晨
# 共有1人不在名单内

# %%
t2=0
jilu2=[]
for i in daoru:
    if i  in name:
        print(i)
        jilu2.append(i)
        t2+=1
print('共有{}人在名单内'.format(t2))
# Out:
# 李振铭
# 蔡晋书
# 王思涵
# 邓骞
# 张雪晨
# 樊孟奇
# 赵启晨
# 李佳欣
# 吕辰杰
# 冷帅
# 叶倪瑄
# 胡雨辰
# 王晨杨
# 梁星
# 胡佳炜
# 简子涵
# 刘佳琦
# 孙思薇
# 余韵婧
# 戚美晨
# 刘旭东
# 赵东虎
# 马旭
# 王思澄
# 徐子璇
# 袁弋鸿
# 王砚轩
# 苏浩文
# 李兆祥
# 刘岳朋
# 樊庶
# 罗冠培
# 蔡依林
# 金筱语
# 丛诺
# 朱紫钰
# 周洋
# 孙颖聪
# 李庆涛
# 何佳萌
# 共有40人在名单内

# %%
#fp1.close()
#fp2.close()
xuehao_new=[]  #用来记录异常姓名对应的学号
for i in jilu2:
    xuehao_new.append(dic2[i])
dic3={}
dic3['学号']=xuehao_new
dic3['姓名']=jilu2
df2=pd.DataFrame(dic3)
fpath1=r'C:\Users\刘佳琦\Desktop\导出.xlsx'
df2.to_excel(fpath1)
